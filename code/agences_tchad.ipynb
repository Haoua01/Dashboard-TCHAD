# %%
import folium
from geopy.geocoders import Nominatim
import time

# Create a geolocator object with an increased timeout
geolocator = Nominatim(user_agent="geoapi", timeout=10)

# Define existing Orabank agency data
agencies_orabank = [
    {"name": "Orabank Agence principale", "address": "Avenue Charles De Gaulle, N'Djamena, Chad"},
    {"name": "Orabank Agence de Djambal Bahr", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"},
    {"name": "Orabank Agence Amriguébé", "address": "Boulevard François Tombalbaye, N'Djamena, Chad"},
    {"name": "Orabank Agence V.I.P", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"},
    {"name": "Orabank Agence Abéché", "address": "Abéché, Chad"},
    {"name": "Orabank Agence Moundou", "address": "Moundou, Chad"},
    {"name": "Orabank Agence Sarh", "address": "Sarh, Chad"},
    {"name": "Orabank Agence Am Timan", "address": "Am Timan, Chad"},
    {"name": "Orabank Agence Pala", "address": "Pala, Chad"},
    {"name": "Orabank Agence Mongo", "address": "Mongo, Chad"}
]

# Define new Ecobank agency data
agencies_ecobank = [
    {"name": "Ecobank Agence principale", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"},
    {"name": "Ecobank Agence Rue de 40m", "address": "Boulevard François Tombalbaye, N'Djamena, Chad"},
    {"name": "Ecobank Agence Paris Congo", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"},
    {"name": "Ecobank Agence Goudji", "address": "Goudji, N'Djamena, Chad"},
    {"name": "Ecobank Agence Chagoua", "address": "Chagoua, N'Djamena, Chad"},
    {"name": "Ecobank Agence Moundou", "address": "Moundou, Chad"},
    {"name": "Ecobank Agence Pala", "address": "Pala, Chad"},
    {"name": "Ecobank Agence Sarh", "address": "Sarh, Chad"},
    {"name": "Ecobank Agence Doba", "address": "Doba, Chad"},
    {"name": "Ecobank Agence Abéché", "address": "Abéché, Chad"},
    {"name": "Ecobank Agence Bongor", "address": "Bongor, Chad"}
]

# Define Coris Bank agency data
agencies_coris = [
    {"name": "Coris Bank Agence VIP", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"},
    {"name": "Coris Bank Agence Rue de 40M", "address": "Rue de 40m, N'Djamena, Chad"},
    {"name": "Coris Bank Agence Centrale", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"},
    {"name": "Coris Bank Agence Chagoua", "address": "Chagoua, N'Djamena, Chad"},
    {"name": "Coris Bank Agence El Niméry", "address": "Avenue Nimery, N'Djamena, Chad"},
    {"name": "Coris Bank Agence Farcha", "address": "Farcha, N'Djamena, Chad"},
    {"name": "Coris Bank Agence Hamama", "address": "Hamama, N'Djamena, Chad"},
    {"name": "Coris Bank Agence Kabalaye", "address": "Kabalaye, N'Djamena, Chad"},
    {"name": "Coris Bank Agence Abéché", "address": "Abéché, Chad"},
    {"name": "Coris Bank Agence Mongo", "address": "Mongo, Chad"},
    {"name": "Coris Bank Agence Doba", "address": "Doba, Chad"},
    {"name": "Coris Bank Agence Moundou", "address": "Moundou, Chad"},
    {"name": "Coris Bank Agence Sarh", "address": "Sarh, Chad"}
]

# Define UBA agency data
agencies_uba = [
    {"name": "UBA Agence principale", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"},
    {"name": "UBA Agence Farcha", "address": "Farcha, N'Djamena, Chad"},
    {"name": "UBA Agence Sabangali", "address": "Sabangali, N'Djamena, Chad"},
    {"name": "UBA Agence Dembé", "address": "Dembé, N'Djamena, Chad"},
    {"name": "UBA Agence Ndjari", "address": "Ndjari, N'Djamena, Chad"},
    {"name": "UBA Agence Gassi", "address": "Gassi, N'Djamena, Chad"}
]

# Define BAC agency data
agencies_bac = [
    {"name": "BAC Agence principale", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"},
]

# Define BCC agency data
agencies_bcc = [
    {"name": "BCC Agence principale", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"},
    {"name": "BCC Agence Rue de 40", "address": "Rue de 40m, N'Djamena, Chad"},
    {"name": "BCC Agence Al Yousr", "address": "Avenue Nimery, N'Djamena, Chad"},
    {"name": "BCC Agence Hamama", "address": "Hamama, N'Djamena, Chad"},
    {"name": "BCC Agence Ambassatna", "address": "Ambassatna, N'Djamena, Chad"},
    {"name": "BCC Agence Tiné", "address": "Tiné, Chad"},
    {"name": "BCC Agence Moundou", "address": "Moundou, Chad"},
    {"name": "BCC Agence Abéché", "address": "Abéché, Chad"}
]

# Define CBT agency data
agencies_cbt = [
    {"name": "CBT Agence principale", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"},
    {"name": "CBT Agence Rue de 40", "address": "Rue de 40m, N'Djamena, Chad"},
    {"name": "CBT Agence Al Yousr", "address": "Avenue Nimery, N'Djamena, Chad"},
    {"name": "CBT Agence Aéroport", "address": "Aéroport, N'Djamena, Chad"},
    {"name": "CBT Agence Ngueli", "address": "Ngueli, N'Djamena, Chad"},
    {"name": "CBT Agence Moundou", "address": "Moundou, Chad"},
    {"name": "CBT Agence Abéché", "address": "Abéché, Chad"}
]

# Define BSIC agency data
agencies_bsic = [
    {"name": "BSIC Agence principale", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"},
    {"name": "BSIC Agence Habbena", "address": "N'Djamena, Chad"},
    {"name": "BSIC Agence Maldom Bada", "address": "Avenue Nimery, N'Djamena, Chad"},
    {"name": "BSIC Agence Marché à Mil", "address": "N'Djamena, Chad"},
    {"name": "BSIC Agence CDG", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"},
    {"name": "BSIC Agence Dembé", "address": "Dembé, N'Djamena, Chad"},
    {"name": "BSIC Agence Abéché", "address": "Abéché, Chad"},
    {"name": "BSIC Agence Bol", "address": "Bol, Chad"},
    {"name": "BSIC Agence Mao", "address": "Mao, Chad"},
    {"name": "BSIC Agence Moundou", "address": "Moundou, Chad"}
]

# Define BHT agency data
agencies_bht = [
    {"name": "BHT Agence principale", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"}
]

# Define Attijari agency data
agencies_attijari = [
    {"name": "Attijari Agence principale", "address": "Avenue Charles de Gaulle, N'Djamena, Chad"}
]


# Combine both agency lists into one
agencies_combined = agencies_orabank + agencies_ecobank + agencies_coris + agencies_uba + agencies_bac + agencies_bcc + agencies_cbt + agencies_bsic + agencies_bht + agencies_attijari

# Create a map centered on Chad
my_map = folium.Map(location=[15.5, 19.5], zoom_start=5)

# Dictionary to keep track of the number of agencies at the same location
location_offsets = {}

# Geocode each agency and add circles to the map
for agency in agencies_combined:
    for attempt in range(3):  # Try up to 3 times
        try:
            agency_location = geolocator.geocode(agency["address"])
            if agency_location:  # Check if geocoding was successful
                # Use the latitude and longitude as the key
                location_key = (agency_location.latitude, agency_location.longitude)
                
                # Calculate the number of agencies at this location
                if location_key not in location_offsets:
                    location_offsets[location_key] = 1
                else:
                    location_offsets[location_key] += 1
                
                # Apply a small vertical offset (if needed for overlapping)
                offset = 0.0001 * (location_offsets[location_key] - 1)  # Adjust if necessary
                
                # Add a circle marker with size based on the number of agencies
                folium.CircleMarker(
                    location=[agency_location.latitude + offset, agency_location.longitude],
                    radius=3 * location_offsets[location_key],  # Adjust size of the circle
                    popup=f"<strong>{agency['name']}</strong><br>{agency['address']}",
                    color="blue",
                    fill=True,
                    fill_color="blue",
                    fill_opacity=0.6
                ).add_to(my_map)
                break  # Exit retry loop if successful
            else:
                print(f"Localisation non trouvée pour {agency['name']} à l'adresse {agency['address']}")
                break  # Exit retry loop if address not found
        except Exception as e:
            print(f"Erreur lors du géocodage de {agency['name']} à l'adresse {agency['address']}: {e}")
            time.sleep(2)  # Wait before retrying

# Save the map as an HTML file
my_map.save("/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-TCHAD/docs/bank_agencies_map.html")

print("La carte a été générée et sauvegardée sous 'bank_agencies_map.html'.")
# Out:
# La carte a été générée et sauvegardée sous 'bank_agencies_map.html'.

# %%
# Define the mapping of cities to their regions
city_to_region = {
    "N'Djamena": "N'Djamena",
    "Abéché": "Ouaddaï",
    "Moundou": "Logone Occidental",
    "Sarh": "Moyen-Chari",
    "Am Timan": "Salamat",
    "Pala": "Mayo-Kebbi Ouest",
    "Mongo": "Guéra",
    "Doba": "Logone Oriental",
    "Bongor": "Mayo-Kebbi Est",
    "Tiné": "Wadi Fira",
    "Bol": "Lac",
    "Mao": "Kanem",
    "Moussoro": "Barh-El-Gazel",
    "Ati": "Batha",
    "Faya-Largeau": "Borkou",
    "Massenya": "Chari-Baguirmi",
    "Am-Djarass": "Ennedi Est",
    "Fada": "Ennedi Ouest",
    "Massakory": "Hadjer-Lamis",
    "Koumra": "Mandoul",
    "Goz Beïda": "Sila",
    "Kélo": "Tandjilé",
    "Bardaï": "Tibesti",
}


# Count the total number of agencies in each city
from collections import Counter

city_counts = Counter()
for agency in agencies_combined:
    # Extract city name from the address
    city = agency['address'].split(", ")[-2]  # Get the city
    city_counts[city] += 1

# Calculate the total number of agencies
total_agencies = len(agencies_combined)
city_counts, total_agencies


# attribute 0 to city_counts for cities without agencies
for city in city_to_region.keys():
    if city not in city_counts:
        city_counts[city] = 0
        print(f"{city} : {city_counts[city]}")

print(city_counts)

#create a dictionary to store the number of agencies in each region and attribute 0 for regions without agencies
region_counts = Counter()
for city, count in city_counts.items():
    region = city_to_region.get(city, "Unknown")
    region_counts[region] += count



#print(region_counts)

#print(neighbors)
# Out:
# Moussoro : 0
# Ati : 0
# Faya-Largeau : 0
# Massenya : 0
# Am-Djarass : 0
# Fada : 0
# Massakory : 0
# Koumra : 0
# Goz Beïda : 0
# Kélo : 0
# Bardaï : 0
# Counter({"N'Djamena": 42, 'Abéché': 6, 'Moundou': 6, 'Sarh': 3, 'Pala': 2, 'Mongo': 2, 'Doba': 2, 'Am Timan': 1, 'Bongor': 1, 'Tiné': 1, 'Bol': 1, 'Mao': 1, 'Moussoro': 0, 'Ati': 0, 'Faya-Largeau': 0, 'Massenya': 0, 'Am-Djarass': 0, 'Fada': 0, 'Massakory': 0, 'Koumra': 0, 'Goz Beïda': 0, 'Kélo': 0, 'Bardaï': 0})

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from geopy.distance import great_circle


#define the coordinates of each region having agencies
coordinates_regions_with_agencies = {
    "N'Djamena": (12.1347, 15.0554),
    "Ouaddaï": (13.8292, 20.8324),
    "Logone Occidental": (8.5667, 16.0833),
    "Moyen-Chari": (9.1429, 18.3923),
    "Salamat": (10.2833, 15.3667),
    "Mayo-Kebbi Ouest": (7.3500, 16.4667),
    "Guéra": (11.0000, 19.5000),
    "Logone Oriental": (8.6500, 16.8500),
    "Mayo-Kebbi Est": (8.9667, 17.5333),
    "Wadi Fira": (17.2833, 21.5833),
    "Lac": (13.1667, 14.1167),
    "Kanem": (13.9667, 13.6667),
}

#define the coordinates of the other regions
coordinates_regions_without_agencies = {
    "Barh-El-Gazel": (13.5000, 20.0000),
    "Batha": (13.2833, 19.6833),
    "Borkou": (19.7500, 18.6667),
    "Chari-Baguirmi": (11.2400, 16.1000),
    "Ennedi Est": (16.4667, 22.4833),
    "Ennedi Ouest": (17.5833, 21.5000),
    "Hadjer-Lamis": (12.8500, 15.4167),
    "Mandoul": (8.5667, 17.2500),
    "Sila": (11.5167, 21.3333),
    "Tandjilé": (9.1333, 16.1000),
    "Tibesti": (21.8333, 17.0000),
}

#combine the two dictionaries
coordinates0 = {**coordinates_regions_with_agencies, **coordinates_regions_without_agencies}

'''
coordinates = {
    "N'Djamena": (12.1348, 15.0557),
    "Abéché": (13.8292, 20.8324),
    "Moundou": (8.5667, 16.0833),
    "Sarh": (9.1500, 18.3833),
    "Am Timan": (11.0333, 20.2833),
    "Pala": (9.3642, 14.9046),
    "Mongo": (12.1844, 18.6930),
    "Doba": (8.6667, 16.8500),
    "Bongor": (10.2806, 15.3722),
    "Goudji": (12.1348, 15.0557),  # Same coordinates as N'Djamena
    "Chagoua": (12.1348, 15.0557),  # Same coordinates as N'Djamena
    "Tiné": (14.9976, 20.4391),
    "Bol": (13.4584, 14.7141),
    "Mao": (14.1211, 15.3105),
    "Moussoro": (13.6415, 16.4887),
    "Ati": (13.2154, 18.3365),
    "Faya-Largeau": (17.9257, 19.1043),
    "Massenya": (11.4034, 16.1709),
    "Am-Djarass": (16.0500, 22.8333),
    "Fada": (17.1856, 21.5811),
    "Massakory": (12.9833, 15.7333),
    "Koumra": (8.9172, 17.5506),
    "Goz Beïda": (12.2242, 21.4106),
    "Kélo": (9.3074, 15.8066),
    "Bardaï": (21.3544, 17.0040)
}
'''


#dictionnary of the area of the different regions

area_regions = {
    "N'Djamena": 21.8,
    "Ouaddaï": 76.8,
    "Logone Occidental": 40.2,
    "Moyen-Chari": 40.3,
    "Salamat": 53.3,
    "Mayo-Kebbi Ouest": 30.7,
    "Guéra": 18.9,
    "Logone Oriental": 27.0,
    "Mayo-Kebbi Est": 29.7,
    "Wadi Fira": 61.3,
    "Lac": 23.3,
    "Kanem": 155.4,
    "Barh-El-Gazel": 86.2,
    "Batha": 64.7,
    "Borkou": 61.3,
    "Chari-Baguirmi": 44.9,
    "Ennedi Est": 61.0,
    "Ennedi Ouest": 96.7,
    "Hadjer-Lamis": 16.1,
    "Mandoul": 22.1,
    "Sila": 25.5,
    "Tandjilé": 11.9,
    "Tibesti": 153.4,
}

# %%
from geopy.geocoders import Nominatim
import time

# Initialize the geocoder
geolocator = Nominatim(user_agent="geoapiExercises")

# Function to get coordinates for a given location
def get_coordinates(location):
    try:
        location_data = geolocator.geocode(location)
        if location_data:
            return (location_data.latitude, location_data.longitude)
        else:
            return None
    except Exception as e:
        print(f"Error fetching coordinates for {location}: {e}")
        return None

# Compute and store the coordinates
coordinates = {}
for city in city_to_region.keys():
    location = f"{city}, Chad"
    #print(location)
    coords = get_coordinates(location)
    if coords:
        coordinates[city] = coords
        print(f"{city}: {coords}")
    else:
        print(f"Coordinates for {city} not found.")
    
    # Be polite to the server and avoid making requests too quickly
    time.sleep(1)

# Print the final dictionary with coordinates
#print("\nFinal coordinates dictionary:")
#print(coordinates)
# Out:
# N'Djamena: (12.1191543, 15.0502758)
# Abéché: (13.8280295, 20.8283652)
# Moundou: (8.5654637, 16.073831)
# Sarh: (9.1406471, 18.3937969)
# Am Timan: (11.0396368, 20.2826429)
# Pala: (9.3662802, 14.9097028)
# Mongo: (12.1842561, 18.6842092)
# Doba: (8.6592029, 16.8538495)
# Bongor: (10.2816341, 15.3713139)
# Tiné: (15.026864, 22.794554)
# Bol: (13.4676491, 14.714412)
# Mao: (14.1234161, 15.3108471)
# Moussoro: (8.3855539, 17.4778564)
# Ati: (13.2125691, 18.3396857)
# Faya-Largeau: (17.9209323, 19.0953202)
# Massenya: (11.40331, 16.17192)
# Am-Djarass: (16.0662879, 22.8350448)
# Fada: (17.1930577, 21.5813259)
# Massakory: (12.996486, 15.7349101)
# Koumra: (8.9189081, 17.5478111)
# Goz Beïda: (12.225592, 21.4101617)
# Kélo: (9.3135075, 15.7869843)
# Bardaï: (21.3549506, 17.0005053)
# N'Djamena : Abéché = 654.26
# N'Djamena : Moundou = 410.70
# N'Djamena : Sarh = 493.13
# N'Djamena : Am Timan = 582.46
# N'Djamena : Pala = 306.49
# N'Djamena : Mongo = 395.09
# N'Djamena : Doba = 432.34
# N'Djamena : Bongor = 207.30
# N'Djamena : Tiné = 897.22
# N'Djamena : Bol = 154.31
# N'Djamena : Mao = 224.64
# N'Djamena : Moussoro = 492.83
# N'Djamena : Ati = 377.00
# N'Djamena : Faya-Largeau = 777.63
# N'Djamena : Massenya = 145.76
# N'Djamena : Am-Djarass = 947.17
# N'Djamena : Fada = 900.85
# N'Djamena : Massakory = 122.63
# N'Djamena : Koumra = 448.51
# N'Djamena : Goz Beïda = 691.37
# N'Djamena : Kélo = 322.19
# N'Djamena : Bardaï = 1047.70
# Abéché : N'Djamena = 654.26
# Abéché : Moundou = 781.78
# Abéché : Sarh = 584.81
# Abéché : Am Timan = 315.67
# Abéché : Pala = 813.34
# Abéché : Mongo = 295.58
# Abéché : Doba = 719.78
# Abéché : Bongor = 712.40
# Abéché : Tiné = 250.20
# Abéché : Bol = 661.84
# Abéché : Mao = 596.25
# Abéché : Moussoro = 706.95
# Abéché : Ati = 277.62
# Abéché : Faya-Largeau = 491.39
# Abéché : Massenya = 572.66
# Abéché : Am-Djarass = 329.26
# Abéché : Fada = 382.77
# Abéché : Massakory = 558.61
# Abéché : Koumra = 652.52
# Abéché : Goz Beïda = 189.00
# Abéché : Kélo = 743.92
# Abéché : Bardaï = 929.95
# Moundou : N'Djamena = 410.70
# Moundou : Abéché = 781.78
# Moundou : Sarh = 262.80
# Moundou : Am Timan = 536.96
# Moundou : Pala = 155.81
# Moundou : Mongo = 493.36
# Moundou : Doba = 86.39
# Moundou : Bongor = 205.80
# Moundou : Tiné = 1025.02
# Moundou : Bol = 564.92
# Moundou : Mao = 623.58
# Moundou : Moussoro = 155.71
# Moundou : Ati = 572.88
# Moundou : Faya-Largeau = 1090.35
# Moundou : Massenya = 315.74
# Moundou : Am-Djarass = 1110.97
# Moundou : Fada = 1129.58
# Moundou : Massakory = 494.10
# Moundou : Koumra = 166.69
# Moundou : Goz Beïda = 711.43
# Moundou : Kélo = 88.95
# Moundou : Bardaï = 1425.59
# Sarh : N'Djamena = 493.13
# Sarh : Abéché = 584.81
# Sarh : Moundou = 262.80
# Sarh : Am Timan = 295.54
# Sarh : Pala = 383.19
# Sarh : Mongo = 339.92
# Sarh : Doba = 177.44
# Sarh : Bongor = 354.73
# Sarh : Tiné = 810.63
# Sarh : Bol = 626.39
# Sarh : Mao = 647.80
# Sarh : Moussoro = 131.08
# Sarh : Ati = 452.82
# Sarh : Faya-Largeau = 979.26
# Sarh : Massenya = 349.84
# Sarh : Am-Djarass = 908.29
# Sarh : Fada = 959.48
# Sarh : Massakory = 517.67
# Sarh : Koumra = 96.12
# Sarh : Goz Beïda = 475.68
# Sarh : Kélo = 286.76
# Sarh : Bardaï = 1366.33
# Am Timan : N'Djamena = 582.46
# Am Timan : Abéché = 315.67
# Am Timan : Moundou = 536.96
# Am Timan : Sarh = 295.54
# Am Timan : Pala = 616.71
# Am Timan : Mongo = 215.66
# Am Timan : Doba = 459.51
# Am Timan : Bongor = 543.26
# Am Timan : Tiné = 520.17
# Am Timan : Bol = 662.50
# Am Timan : Mao = 639.23
# Am Timan : Moussoro = 426.12
# Am Timan : Ati = 320.92
# Am Timan : Faya-Largeau = 775.76
# Am Timan : Massenya = 450.17
# Am Timan : Am-Djarass = 623.28
# Am Timan : Fada = 698.40
# Am Timan : Massakory = 540.32
# Am Timan : Koumra = 381.18
# Am Timan : Goz Beïda = 180.19
# Am Timan : Kélo = 528.12
# Am Timan : Bardaï = 1199.19
# Pala : N'Djamena = 306.49
# Pala : Abéché = 813.34
# Pala : Moundou = 155.81
# Pala : Sarh = 383.19
# Pala : Am Timan = 616.71
# Pala : Mongo = 517.82
# Pala : Doba = 227.53
# Pala : Bongor = 113.66
# Pala : Tiné = 1062.94
# Pala : Bol = 456.55
# Pala : Mao = 530.77
# Pala : Moussoro = 302.48
# Pala : Ati = 568.11
# Pala : Faya-Largeau = 1053.07
# Pala : Massenya = 265.26
# Pala : Am-Djarass = 1137.10
# Pala : Fada = 1130.38
# Pala : Massakory = 413.57
# Pala : Koumra = 293.86
# Pala : Goz Beïda = 777.87
# Pala : Kélo = 96.43
# Pala : Bardaï = 1351.72
# Mongo : N'Djamena = 395.09
# Mongo : Abéché = 295.58
# Mongo : Moundou = 493.36
# Mongo : Sarh = 339.92
# Mongo : Am Timan = 215.66
# Mongo : Pala = 517.82
# Mongo : Doba = 440.11
# Mongo : Bongor = 418.68
# Mongo : Tiné = 545.15
# Mongo : Bol = 453.44
# Mongo : Mao = 424.14
# Mongo : Moussoro = 442.53
# Mongo : Ati = 120.30
# Mongo : Faya-Largeau = 639.41
# Mongo : Massenya = 286.91
# Mongo : Am-Djarass = 621.76
# Mongo : Fada = 638.14
# Mongo : Massakory = 332.56
# Mongo : Koumra = 383.75
# Mongo : Goz Beïda = 296.30
# Mongo : Kélo = 449.50
# Mongo : Bardaï = 1035.33
# Doba : N'Djamena = 432.34
# Doba : Abéché = 719.78
# Doba : Moundou = 86.39
# Doba : Sarh = 177.44
# Doba : Am Timan = 459.51
# Doba : Pala = 227.53
# Doba : Mongo = 440.11
# Doba : Bongor = 242.87
# Doba : Tiné = 958.55
# Doba : Bol = 583.40
# Doba : Mao = 630.42
# Doba : Moussoro = 75.06
# Doba : Ati = 531.65
# Doba : Faya-Largeau = 1057.97
# Doba : Massenya = 314.13
# Doba : Am-Djarass = 1048.68
# Doba : Fada = 1078.14
# Doba : Massakory = 497.52
# Doba : Koumra = 81.54
# Doba : Goz Beïda = 636.73
# Doba : Kélo = 137.92
# Doba : Bardaï = 1411.79
# Bongor : N'Djamena = 207.30
# Bongor : Abéché = 712.40
# Bongor : Moundou = 205.80
# Bongor : Sarh = 354.73
# Bongor : Am Timan = 543.26
# Bongor : Pala = 113.66
# Bongor : Mongo = 418.68
# Bongor : Doba = 242.87
# Bongor : Tiné = 962.59
# Bongor : Bol = 361.41
# Bongor : Mao = 427.24
# Bongor : Moussoro = 312.84
# Bongor : Ati = 458.93
# Bongor : Faya-Largeau = 939.45
# Bongor : Massenya = 152.32
# Bongor : Am-Djarass = 1032.50
# Bongor : Fada = 1019.75
# Bongor : Massakory = 304.46
# Bongor : Koumra = 282.67
# Bongor : Goz Beïda = 693.10
# Bongor : Kélo = 116.89
# Bongor : Bardaï = 1243.53
# Tiné : N'Djamena = 897.22
# Tiné : Abéché = 250.20
# Tiné : Moundou = 1025.02
# Tiné : Sarh = 810.63
# Tiné : Am Timan = 520.17
# Tiné : Pala = 1062.94
# Tiné : Mongo = 545.15
# Tiné : Doba = 958.55
# Tiné : Bongor = 962.59
# Tiné : Bol = 887.85
# Tiné : Mao = 811.57
# Tiné : Moussoro = 938.10
# Tiné : Ati = 521.01
# Tiné : Faya-Largeau = 509.02
# Tiné : Massenya = 822.23
# Tiné : Am-Djarass = 115.66
# Tiné : Fada = 273.52
# Tiné : Massakory = 794.33
# Tiné : Koumra = 886.93
# Tiné : Goz Beïda = 345.54
# Tiné : Kélo = 991.57
# Tiné : Bardaï = 932.32
# Bol : N'Djamena = 154.31
# Bol : Abéché = 661.84
# Bol : Moundou = 564.92
# Bol : Sarh = 626.39
# Bol : Am Timan = 662.50
# Bol : Pala = 456.55
# Bol : Mongo = 453.44
# Bol : Doba = 583.40
# Bol : Bongor = 361.41
# Bol : Tiné = 887.85
# Bol : Mao = 97.29
# Bol : Moussoro = 640.55
# Bol : Ati = 393.26
# Bol : Faya-Largeau = 681.91
# Bol : Massenya = 278.81
# Bol : Am-Djarass = 919.59
# Bol : Fada = 844.75
# Bol : Massakory = 122.26
# Bol : Koumra = 592.70
# Bol : Goz Beïda = 738.88
# Bol : Kélo = 476.48
# Bol : Bardaï = 909.89
# Mao : N'Djamena = 224.64
# Mao : Abéché = 596.25
# Mao : Moundou = 623.58
# Mao : Sarh = 647.80
# Mao : Am Timan = 639.23
# Mao : Pala = 530.77
# Mao : Mongo = 424.14
# Mao : Doba = 630.42
# Mao : Bongor = 427.24
# Mao : Tiné = 811.57
# Mao : Bol = 97.29
# Mao : Moussoro = 680.35
# Mao : Ati = 342.56
# Mao : Faya-Largeau = 584.66
# Mao : Massenya = 316.55
# Mao : Am-Djarass = 836.09
# Mao : Fada = 753.05
# Mao : Massakory = 133.43
# Mao : Koumra = 627.91
# Mao : Goz Beïda = 693.21
# Mao : Kélo = 537.34
# Mao : Bardaï = 823.75
# Moussoro : N'Djamena = 492.83
# Moussoro : Abéché = 706.95
# Moussoro : Moundou = 155.71
# Moussoro : Sarh = 131.08
# Moussoro : Am Timan = 426.12
# Moussoro : Pala = 302.48
# Moussoro : Mongo = 442.53
# Moussoro : Doba = 75.06
# Moussoro : Bongor = 312.84
# Moussoro : Tiné = 938.10
# Moussoro : Bol = 640.55
# Moussoro : Mao = 680.35
# Moussoro : Ati = 544.93
# Moussoro : Faya-Largeau = 1074.62
# Moussoro : Massenya = 364.77
# Moussoro : Am-Djarass = 1033.33
# Moussoro : Fada = 1075.49
# Moussoro : Massakory = 546.92
# Moussoro : Koumra = 59.80
# Moussoro : Goz Beïda = 606.07
# Moussoro : Kélo = 212.51
# Moussoro : Bardaï = 1443.04
# Ati : N'Djamena = 377.00
# Ati : Abéché = 277.62
# Ati : Moundou = 572.88
# Ati : Sarh = 452.82
# Ati : Am Timan = 320.92
# Ati : Pala = 568.11
# Ati : Mongo = 120.30
# Ati : Doba = 531.65
# Ati : Bongor = 458.93
# Ati : Tiné = 521.01
# Ati : Bol = 393.26
# Ati : Mao = 342.56
# Ati : Moussoro = 544.93
# Ati : Faya-Largeau = 529.76
# Ati : Massenya = 309.73
# Ati : Am-Djarass = 578.38
# Ati : Fada = 562.88
# Ati : Massakory = 283.12
# Ati : Koumra = 485.19
# Ati : Goz Beïda = 350.65
# Ati : Kélo = 515.20
# Ati : Bardaï = 916.47
# Faya-Largeau : N'Djamena = 777.63
# Faya-Largeau : Abéché = 491.39
# Faya-Largeau : Moundou = 1090.35
# Faya-Largeau : Sarh = 979.26
# Faya-Largeau : Am Timan = 775.76
# Faya-Largeau : Pala = 1053.07
# Faya-Largeau : Mongo = 639.41
# Faya-Largeau : Doba = 1057.97
# Faya-Largeau : Bongor = 939.45
# Faya-Largeau : Tiné = 509.02
# Faya-Largeau : Bol = 681.91
# Faya-Largeau : Mao = 584.66
# Faya-Largeau : Moussoro = 1074.62
# Faya-Largeau : Ati = 529.76
# Faya-Largeau : Massenya = 789.94
# Faya-Largeau : Am-Djarass = 447.95
# Faya-Largeau : Fada = 275.70
# Faya-Largeau : Massakory = 655.32
# Faya-Largeau : Koumra = 1014.84
# Faya-Largeau : Goz Beïda = 680.27
# Faya-Largeau : Kélo = 1021.56
# Faya-Largeau : Bardaï = 440.36
# Massenya : N'Djamena = 145.76
# Massenya : Abéché = 572.66
# Massenya : Moundou = 315.74
# Massenya : Sarh = 349.84
# Massenya : Am Timan = 450.17
# Massenya : Pala = 265.26
# Massenya : Mongo = 286.91
# Massenya : Doba = 314.13
# Massenya : Bongor = 152.32
# Massenya : Tiné = 822.23
# Massenya : Bol = 278.81
# Massenya : Mao = 316.55
# Massenya : Moussoro = 364.77
# Massenya : Ati = 309.73
# Massenya : Faya-Largeau = 789.94
# Massenya : Am-Djarass = 886.83
# Massenya : Fada = 868.24
# Massenya : Massakory = 183.41
# Massenya : Koumra = 314.63
# Massenya : Goz Beïda = 577.40
# Massenya : Kélo = 236.16
# Massenya : Bardaï = 1110.09
# Am-Djarass : N'Djamena = 947.17
# Am-Djarass : Abéché = 329.26
# Am-Djarass : Moundou = 1110.97
# Am-Djarass : Sarh = 908.29
# Am-Djarass : Am Timan = 623.28
# Am-Djarass : Pala = 1137.10
# Am-Djarass : Mongo = 621.76
# Am-Djarass : Doba = 1048.68
# Am-Djarass : Bongor = 1032.50
# Am-Djarass : Tiné = 115.66
# Am-Djarass : Bol = 919.59
# Am-Djarass : Mao = 836.09
# Am-Djarass : Moussoro = 1033.33
# Am-Djarass : Ati = 578.38
# Am-Djarass : Faya-Largeau = 447.95
# Am-Djarass : Massenya = 886.83
# Am-Djarass : Fada = 183.14
# Am-Djarass : Massakory = 836.88
# Am-Djarass : Koumra = 980.10
# Am-Djarass : Goz Beïda = 453.85
# Am-Djarass : Kélo = 1071.24
# Am-Djarass : Bardaï = 850.31
# Fada : N'Djamena = 900.85
# Fada : Abéché = 382.77
# Fada : Moundou = 1129.58
# Fada : Sarh = 959.48
# Fada : Am Timan = 698.40
# Fada : Pala = 1130.38
# Fada : Mongo = 638.14
# Fada : Doba = 1078.14
# Fada : Bongor = 1019.75
# Fada : Tiné = 273.52
# Fada : Bol = 844.75
# Fada : Mao = 753.05
# Fada : Moussoro = 1075.49
# Fada : Ati = 562.88
# Fada : Faya-Largeau = 275.70
# Fada : Massenya = 868.24
# Fada : Am-Djarass = 183.14
# Fada : Massakory = 781.97
# Fada : Koumra = 1018.32
# Fada : Goz Beïda = 552.66
# Fada : Kélo = 1077.14
# Fada : Bardaï = 667.23
# Massakory : N'Djamena = 122.63
# Massakory : Abéché = 558.61
# Massakory : Moundou = 494.10
# Massakory : Sarh = 517.67
# Massakory : Am Timan = 540.32
# Massakory : Pala = 413.57
# Massakory : Mongo = 332.56
# Massakory : Doba = 497.52
# Massakory : Bongor = 304.46
# Massakory : Tiné = 794.33
# Massakory : Bol = 122.26
# Massakory : Mao = 133.43
# Massakory : Moussoro = 546.92
# Massakory : Ati = 283.12
# Massakory : Faya-Largeau = 655.32
# Massakory : Massenya = 183.41
# Massakory : Am-Djarass = 836.88
# Massakory : Fada = 781.97
# Massakory : Koumra = 494.70
# Massakory : Goz Beïda = 621.76
# Massakory : Kélo = 409.57
# Massakory : Bardaï = 939.07
# Koumra : N'Djamena = 448.51
# Koumra : Abéché = 652.52
# Koumra : Moundou = 166.69
# Koumra : Sarh = 96.12
# Koumra : Am Timan = 381.18
# Koumra : Pala = 293.86
# Koumra : Mongo = 383.75
# Koumra : Doba = 81.54
# Koumra : Bongor = 282.67
# Koumra : Tiné = 886.93
# Koumra : Bol = 592.70
# Koumra : Mao = 627.91
# Koumra : Moussoro = 59.80
# Koumra : Ati = 485.19
# Koumra : Faya-Largeau = 1014.84
# Koumra : Massenya = 314.63
# Koumra : Am-Djarass = 980.10
# Koumra : Fada = 1018.32
# Koumra : Massakory = 494.70
# Koumra : Goz Beïda = 559.80
# Koumra : Kélo = 198.24
# Koumra : Bardaï = 1384.07
# Goz Beïda : N'Djamena = 691.37
# Goz Beïda : Abéché = 189.00
# Goz Beïda : Moundou = 711.43
# Goz Beïda : Sarh = 475.68
# Goz Beïda : Am Timan = 180.19
# Goz Beïda : Pala = 777.87
# Goz Beïda : Mongo = 296.30
# Goz Beïda : Doba = 636.73
# Goz Beïda : Bongor = 693.10
# Goz Beïda : Tiné = 345.54
# Goz Beïda : Bol = 738.88
# Goz Beïda : Mao = 693.21
# Goz Beïda : Moussoro = 606.07
# Goz Beïda : Ati = 350.65
# Goz Beïda : Faya-Largeau = 680.27
# Goz Beïda : Massenya = 577.40
# Goz Beïda : Am-Djarass = 453.85
# Goz Beïda : Fada = 552.66
# Goz Beïda : Massakory = 621.76
# Goz Beïda : Koumra = 559.80
# Goz Beïda : Kélo = 694.31
# Goz Beïda : Bardaï = 1118.15
# Kélo : N'Djamena = 322.19
# Kélo : Abéché = 743.92
# Kélo : Moundou = 88.95
# Kélo : Sarh = 286.76
# Kélo : Am Timan = 528.12
# Kélo : Pala = 96.43
# Kélo : Mongo = 449.50
# Kélo : Doba = 137.92
# Kélo : Bongor = 116.89
# Kélo : Tiné = 991.57
# Kélo : Bol = 476.48
# Kélo : Mao = 537.34
# Kélo : Moussoro = 212.51
# Kélo : Ati = 515.20
# Kélo : Faya-Largeau = 1021.56
# Kélo : Massenya = 236.16
# Kélo : Am-Djarass = 1071.24
# Kélo : Fada = 1077.14
# Kélo : Massakory = 409.57
# Kélo : Koumra = 198.24
# Kélo : Goz Beïda = 694.31
# Kélo : Bardaï = 1345.23
# Bardaï : N'Djamena = 1047.70
# Bardaï : Abéché = 929.95
# Bardaï : Moundou = 1425.59
# Bardaï : Sarh = 1366.33
# Bardaï : Am Timan = 1199.19
# Bardaï : Pala = 1351.72
# Bardaï : Mongo = 1035.33
# Bardaï : Doba = 1411.79
# Bardaï : Bongor = 1243.53
# Bardaï : Tiné = 932.32
# Bardaï : Bol = 909.89
# Bardaï : Mao = 823.75
# Bardaï : Moussoro = 1443.04
# Bardaï : Ati = 916.47
# Bardaï : Faya-Largeau = 440.36
# Bardaï : Massenya = 1110.09
# Bardaï : Am-Djarass = 850.31
# Bardaï : Fada = 667.23
# Bardaï : Massakory = 939.07
# Bardaï : Koumra = 1384.07
# Bardaï : Goz Beïda = 1118.15
# Bardaï : Kélo = 1345.23

# %%
# Compute distances
neighbors = {}

for city1, coords1 in coordinates.items():
    neighbors[city1] = {}
    for city2, coords2 in coordinates.items():
        if city1 != city2:
            distance = great_circle(coords1, coords2).kilometers
            neighbors[city1][city2] = distance
            #print(f"{city1} : {city2} = {distance:.2f}")
# Out:
# 0

# %%
"""ISIBF score for each city"""

# Function to calculate ISIBF

def calculate_isibf1(city_counts, neighbors, alpha, threshold):
    isibf_values = {}
    contributions_voisins={}
    contribution_propre={}
    for city in city_counts:
        total = 0
        for neighbor, distance in neighbors[city].items():
            if distance <= threshold:
                total += (city_counts[neighbor] + 1) / alpha**distance
            else:
                total += 0
        #print(f"{city_to_region[city]}, contribution des voisins = {total:.2f}, contribution propre = {(city_counts[city] + 1):.2f}")
        contributions_voisins[city] = total
        contribution_propre[city] = (city_counts[city] + 1)
        total+= (city_counts[city] + 1)
        isibf_values[city] = total
    #apply mapping to regions for isibf_values
    isibf_values = {city_to_region.get(k, k): v for k, v in isibf_values.items()}
    return contribution_propre, contributions_voisins, isibf_values 


alpha=1.008
threshold = 400
isibf_scores0 = calculate_isibf1(city_counts, neighbors, alpha, threshold)
#print(isibf_scores0)
# min-max normalization

def min_max_normalize(values):
    min_value = min(values.values())
    max_value = max(values.values())
    normalized_values = {}
    for key, value in values.items():
        normalized_values[key] = (value - min_value) / (max_value - min_value)
        #print(f"{key}: {normalized_values[key]:.2f}")
    return normalized_values

#plot contribution of neighbors and propre contribution for each city

contribution_propre, contributions_voisins, isibf_values = isibf_scores0

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 8))

# Plot the contributions of neighbors
ax.barh(list(contributions_voisins.keys()), list(contributions_voisins.values()), color='skyblue', label='Contribution des voisins')

# Plot the contributions of the cities themselves
ax.barh(list(contribution_propre.keys()), list(contribution_propre.values()), color='salmon', label='Contribution propre')

#ax.barh(list(isibf_values.keys()), list(isibf_values.values()), color='green', label='ISIBF')


# Add labels and title

ax.set_xlabel('Score')
ax.set_ylabel('Chef-Lieu')
ax.set_title('Contibutions aux scores')
ax.legend()

# %%
isibf_scores = min_max_normalize(isibf_values)

print(isibf_values)

#apply .2f to the values of the dictionary and map to regions

isibf_scores = {k: round(v, 2) for k, v in isibf_scores.items()}

# Print the ISIBF scores
print("\nISIBF scores:")
print(isibf_scores)
# Out:
# {"N'Djamena": 45.50766463875456, 'Ouaddaï': 8.169852901593913, 'Logone Occidental': 11.381989645293205, 'Moyen-Chari': 7.2218456905901585, 'Salamat': 3.8469635217993714, 'Mayo-Kebbi Ouest': 11.019738932791322, 'Guéra': 6.832567170450238, 'Logone Oriental': 9.754984445108175, 'Mayo-Kebbi Est': 14.563743658839066, 'Wadi Fira': 3.5280949534128396, 'Lac': 16.137499376691515, 'Kanem': 10.591401353793364, 'Barh-El-Gazel': 7.375592647491379, 'Batha': 5.672282205218386, 'Borkou': 1.1111571461628258, 'Chari-Baguirmi': 17.76242092977492, 'Ennedi Est': 2.5359603296368958, 'Ennedi Ouest': 1.9012845376308207, 'Hadjer-Lamis': 19.355700622626653, 'Mandoul': 7.925050678436704, 'Sila': 3.500019050434843, 'Tandjilé': 11.874229384392272, 'Tibesti': 1}
#
# ISIBF scores:
# {"N'Djamena": 1.0, 'Ouaddaï': 0.16, 'Logone Occidental': 0.23, 'Moyen-Chari': 0.14, 'Salamat': 0.06, 'Mayo-Kebbi Ouest': 0.23, 'Guéra': 0.13, 'Logone Oriental': 0.2, 'Mayo-Kebbi Est': 0.3, 'Wadi Fira': 0.06, 'Lac': 0.34, 'Kanem': 0.22, 'Barh-El-Gazel': 0.14, 'Batha': 0.1, 'Borkou': 0.0, 'Chari-Baguirmi': 0.38, 'Ennedi Est': 0.03, 'Ennedi Ouest': 0.02, 'Hadjer-Lamis': 0.41, 'Mandoul': 0.16, 'Sila': 0.06, 'Tandjilé': 0.24, 'Tibesti': 0.0}

# %% [markdown]
# On veut $\alpha$ tel que $ max_{i}\sum_{j\neq i, d_{i,j}<\delta} \frac{log_{2}(N_{j}+1)}{\alpha ^{d_{i,j}}} \leq max_{i} log_{2}(N_{i}+1)$

# %%
# Load the shapefile
tchad = gpd.read_file('/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-TCHAD/docs/tcd_admbnda_adm1_ocha/tcd_admbnda_adm1_ocha.shp')


tchad['ISIBF'] = tchad['admin1Name'].map(isibf_scores)
# Plot the map
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
tchad.plot(column='ISIBF', ax=ax, legend=True, cmap='Blues', legend_kwds={'label': f'ISIBF score for alpha={alpha}'}, edgecolor='grey')
ax.set_title(f'ISIBF score for alpha={alpha}')
plt.show()

# %%
#make the map interactive with folium

# Create a map centered on Chad
my_map = folium.Map(location=[15.5, 19.5], zoom_start=5)

# Add the ISIBF scores to the GeoDataFrame

tchad['ISIBF'] = tchad['admin1Name'].map(isibf_scores)

# Plot the map
folium.Choropleth(
    geo_data=tchad,
    name='choropleth',
    data=tchad,
    columns=['admin1Name', 'ISIBF'],
    key_on='feature.properties.admin1Name',
    fill_color='YlGn',
    fill_opacity=0.9,
    line_opacity=0.2,
    legend_name='ISIBF score'
).add_to(my_map)

# Add a tooltip to display information
folium.GeoJson(
    tchad.__geo_interface__,
    style_function=lambda feature: {
        'fillColor': 'YlGn' if feature['properties']['ISIBF'] is not None else 'gray',
        'color': 'black',
        'weight': 0.5,
        'fillOpacity': 0.2,
    },
    tooltip=folium.GeoJsonTooltip(
        fields=['admin1Name', 'ISIBF'],
        aliases=['Region:', 'ISIBF Score:'],
        localize=True,
    )
).add_to(my_map)

# Save the map as an HTML file
my_map.save("/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/Dashboard/Tchad/isibf_map2.html")

# %%
#!pip install plotly
import geopandas as gpd
import plotly.express as px

tchad['ISIBF'] = tchad['admin1Name'].map(isibf_scores)

# Convert to GeoJSON
geojson_data = tchad.__geo_interface__

fig = px.choropleth_mapbox(
    tchad,
    geojson=geojson_data,
    locations='admin1Name',  # Location column in your GeoDataFrame
    featureidkey='properties.admin1Name',  # This should match the GeoJSON structure
    color='ISIBF',  # Fill color with ISIBF scores
    mapbox_style="carto-positron",
    zoom=4.9,
    center={"lat": 15.5, "lon": 19.5},
    title="Score d'accès aux agences bancaires par régions au Tchad",
    hover_name="admin1Name",  # Region names
    hover_data={'ISIBF': True, 'admin1Name': False},  # Show ISIBF score but hide original name
    labels={'admin1Name': 'Région', 'ISIBF': 'ISIBF Score'},
    color_continuous_scale=px.colors.sequential.Blues,  # Light to dark blue color scale
)

# Save as HTML
fig.write_html('/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-TCHAD/docs/isibf_tchad_map.html')
